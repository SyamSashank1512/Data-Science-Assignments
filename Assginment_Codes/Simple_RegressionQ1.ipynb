# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\SHYAM SASHANK\OneDrive\Desktop\Data_Science\Assginment_CSV\Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x=df["YearsExperience"]
x
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64

# %%
y=df["Salary"]
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
import statsmodels.formula.api as smf

# %%
model1=smf.ols('Salary~YearsExperience',data=df).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           1.14e-20
# Time:                        20:45:39   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
#Method 2

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(df[["YearsExperience"]],df.Salary)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([9449.96232146])

# %%
lm.intercept_
# Out:
# 25792.200198668717

# %%
lm.predict([[2]])
# Out:
# C:\Users\SHYAM SASHANK\anaconda3\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44692.12484158])

# %%
a=9449.96232146*2+25792.200198668717
a
# Out:
# 44692.12484158872

# %%
plt.scatter(df["YearsExperience"],y)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
x=np.array(x).reshape((-1,1))
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
# array([[ 7.9],
#        [ 2.9],
#        [ 5.1],
#        [ 3.2],
#        [ 4.5],
#        [ 8.2],
#        [ 6.8],
#        [ 1.3],
#        [10.5],
#        [ 3. ],
#        [ 2.2],
#        [ 5.9],
#        [ 6. ],
#        [ 3.7],
#        [ 3.2],
#        [ 9. ],
#        [ 2. ],
#        [ 1.1],
#        [ 7.1],
#        [ 4.9],
#        [ 4. ]])

# %%
X_test
# Out:
# array([[ 1.5],
#        [10.3],
#        [ 4.1],
#        [ 3.9],
#        [ 9.5],
#        [ 8.7],
#        [ 9.6],
#        [ 4. ],
#        [ 5.3]])

# %%
Y_train
# Out:
# 22    101302.0
# 5      56642.0
# 16     66029.0
# 8      64445.0
# 14     61111.0
# 23    113812.0
# 20     91738.0
# 1      46205.0
# 29    121872.0
# 6      60150.0
# 4      39891.0
# 18     81363.0
# 19     93940.0
# 9      57189.0
# 7      54445.0
# 25    105582.0
# 3      43525.0
# 0      39343.0
# 21     98273.0
# 15     67938.0
# 12     56957.0
# Name: Salary, dtype: float64

# %%
Y_test
# Out:
# 2      37731.0
# 28    122391.0
# 13     57081.0
# 10     63218.0
# 26    116969.0
# 24    109431.0
# 27    112635.0
# 11     55794.0
# 17     83088.0
# Name: Salary, dtype: float64

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_train.shape
# Out:
# (21, 1)

# %%
X_test.shape
# Out:
# (9, 1)

# %%
Y_train.shape
# Out:
# (21,)

# %%
Y_test.shape
# Out:
# (9,)

# %%
lm.coef_
# Out:
# array([9360.26128619])

# %%
lm.intercept_
# Out:
# 26777.39134119764

# %%
y_predict_train=lm.predict(X_train)
y_predict_train
# Out:
# array([100723.45550213,  53922.14907116,  74514.72390079,  56730.22745702,
#         68898.56712907, 103531.53388799,  90427.16808731,  38945.73101325,
#        125060.13484623,  54858.17519978,  47369.96617082,  82002.93292974,
#         82938.95905836,  61410.35810011,  56730.22745702, 111019.74291694,
#         45497.91391358,  37073.67875601,  93235.24647317,  72642.67164355,
#         64218.43648597])

# %%
y_predict_test=lm.predict(X_test)
y_predict_test
# Out:
# array([ 40817.78327049, 123188.08258899,  65154.46261459,  63282.41035735,
#        115699.87356004, 108211.66453108, 116635.89968866,  64218.43648597,
#         76386.77615802])

# %%
plt.scatter( X_test,Y_test, color="black")
plt.plot(X_test,y_predict_test, color="blue")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
mse =mean_squared_error(Y_test,y_predict_test)
mse
# Out:
# 23370078.800832972

# %%
from sklearn.metrics import r2_score
score = r2_score(Y_test,y_predict_test)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
# Out:
# The accuracy of our model is 97.0%

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
score = np.sqrt(mean_squared_error(Y_test,y_predict_test))
print("The Root Mean Squared Error of our Model is {}".format(round(score, 2)))
# Out:
# The Root Mean Squared Error of our Model is 4834.26

# %% [markdown]
# # Using the LOG function

# %%
#Converting the y dataset in Log function

df['Log_Salary']=np.log2(df["Salary"])
df
# Out:
#     YearsExperience    Salary  Log_Salary
# 0               1.1   39343.0   15.263819
# 1               1.3   46205.0   15.495761
# 2               1.5   37731.0   15.203463
# 3               2.0   43525.0   15.409557
# 4               2.2   39891.0   15.283776
# 5               2.9   56642.0   15.789585
# 6               3.0   60150.0   15.876277
# 7               3.2   54445.0   15.732512
# 8               3.2   64445.0   15.975781
# 9               3.7   57189.0   15.803450
# 10              3.9   63218.0   15.948048
# 11              4.0   55794.0   15.767822
# 12              4.0   56957.0   15.797586
# 13              4.1   57081.0   15.800723
# 14              4.5   61111.0   15.899144
# 15              4.9   67938.0   16.051931
# 16              5.1   66029.0   16.010812
# 17              5.3   83088.0   16.342353
# 18              5.9   81363.0   16.312085
# 19              6.0   93940.0   16.519452
# 20              6.8   91738.0   16.485232
# ...

# %%
model2=smf.ols('Log_Salary~YearsExperience',data=df).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Log_Salary   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     383.6
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           7.03e-18
# Time:                        20:45:40   Log-Likelihood:                 17.188
# No. Observations:                  30   AIC:                            -30.38
# Df Residuals:                      28   BIC:                            -27.57
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
y1=df[["Log_Salary"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y1, random_state=2, test_size=0.2)

# %%
x_train
# Out:
# array([[ 8.2],
#        [ 3. ],
#        [ 2. ],
#        [ 6.8],
#        [ 2.9],
#        [ 9.6],
#        [ 4. ],
#        [ 2.2],
#        [ 3.9],
#        [ 5.1],
#        [10.3],
#        [ 9. ],
#        [ 5.3],
#        [ 1.5],
#        [ 3.2],
#        [ 9.5],
#        [ 8.7],
#        [ 5.9],
#        [ 4. ],
#        [ 7.9],
#        [10.5],
#        [ 4.1],
#        [ 4.9],
#        [ 3.2]])

# %%
x_test
# Out:
# array([[1.3],
#        [1.1],
#        [4.5],
#        [3.7],
#        [7.1],
#        [6. ]])

# %%
y_train
# Out:
#     Log_Salary
# 23   16.796293
# 6    15.876277
# 3    15.409557
# 20   16.485232
# 5    15.789585
# 27   16.781296
# 12   15.797586
# 4    15.283776
# 10   15.948048
# 16   16.010812
# 28   16.901138
# 25   16.688004
# 17   16.342353
# 2    15.203463
# 7    15.732512
# 26   16.835767
# 24   16.739662
# 18   16.312085
# 11   15.767822
# 22   16.628303
# 29   16.895007
# 13   15.800723
# 15   16.051931
# 8    15.975781

# %%
y_test
# Out:
#     Log_Salary
# 1    15.495761
# 0    15.263819
# 14   15.899144
# 9    15.803450
# 21   16.584507
# 19   16.519452

# %%
from sklearn.linear_model import LinearRegression

# %%
lr1=LinearRegression()

# %%
lr1.fit(x,y1)
# Out:
# LinearRegression()

# %%
y_pred=lr1.predict(x_train)

# %%
y_pred
# Out:
# array([[16.64309675],
#        [15.70194739],
#        [15.52095713],
#        [16.38971039],
#        [15.68384837],
#        [16.89648312],
#        [15.88293765],
#        [15.55715518],
#        [15.86483863],
#        [16.08202694],
#        [17.0231763 ],
#        [16.78788896],
#        [16.11822499],
#        [15.430462  ],
#        [15.73814544],
#        [16.87838409],
#        [16.73359188],
#        [16.22681915],
#        [15.88293765],
#        [16.58879967],
#        [17.05937435],
#        [15.90103668],
#        [16.04582889],
#        [15.73814544]])

# %%
y_pred_test=lr1.predict(x_test)

# %%
y_pred_test
# Out:
# array([[15.39426395],
#        [15.3580659 ],
#        [15.97343278],
#        [15.82864058],
#        [16.44400746],
#        [16.24491818]])

# %%
plt.scatter(df["YearsExperience"],y1)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x_test,y_test,color="red")
plt.plot(x_test,y_pred_test,linewidth=3,color="green")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
mse =mean_squared_error(y_test,y_pred_test)
mse
# Out:
# 0.020074418562480326

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 0.1416842212897411

# %%
df
# Out:
#     YearsExperience    Salary  Log_Salary
# 0               1.1   39343.0   15.263819
# 1               1.3   46205.0   15.495761
# 2               1.5   37731.0   15.203463
# 3               2.0   43525.0   15.409557
# 4               2.2   39891.0   15.283776
# 5               2.9   56642.0   15.789585
# 6               3.0   60150.0   15.876277
# 7               3.2   54445.0   15.732512
# 8               3.2   64445.0   15.975781
# 9               3.7   57189.0   15.803450
# 10              3.9   63218.0   15.948048
# 11              4.0   55794.0   15.767822
# 12              4.0   56957.0   15.797586
# 13              4.1   57081.0   15.800723
# 14              4.5   61111.0   15.899144
# 15              4.9   67938.0   16.051931
# 16              5.1   66029.0   16.010812
# 17              5.3   83088.0   16.342353
# 18              5.9   81363.0   16.312085
# 19              6.0   93940.0   16.519452
# 20              6.8   91738.0   16.485232
# ...

# %%
lr1.coef_
# Out:
# array([[0.18099026]])

# %%
lr1.intercept_
# Out:
# array([15.15897661])

# %%
lr1.predict([[3]])
# Out:
# array([[15.70194739]])

# %%
a1=0.18099026*3+15.15897661
a1
# Out:
# 15.701947389999999

# %%
from sklearn.metrics import r2_score
score = r2_score(y_train,y_pred)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
# Out:
# The accuracy of our model is 93.0%
