# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a1=np.array([1,4,3,5,6,2])
b1=np.array([0.015,0.20,0.65,0.005,0.01,0.120])

# %%
c1=(a1*b1).sum()

# %%
c1
# Out:
# 3.09
