# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
import seaborn as sbn

# %%
df=pd.read_csv(r'C:\Users\SHYAM SASHANK\OneDrive\Desktop\Data_Science\class_codes\Toyoto_Corrola.csv')

# %%
df.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3  ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#       KM  HP  Doors  Cylinders  Gears  Weight
# 0  46986  90      3          4      5    1165
# 1  72937  90      3          4      5    1165
# 2  41711  90      3          4      5    1165
# 3  48000  90      3          4      5    1165
# 4  38500  90      3          4      5    1170

# %%
sbn.scatterplot(x='Age_08_04',y='Price',data=df)
# Out:
# <AxesSubplot:xlabel='Age_08_04', ylabel='Price'>

# %%
d1=df.drop(columns=["Doors","Cylinders","Gears","Id","Model","Price"])

# %%
d1
# Out:
#       Age_08_04     KM   HP  Weight
# 0            23  46986   90    1165
# 1            23  72937   90    1165
# 2            24  41711   90    1165
# 3            26  48000   90    1165
# 4            30  38500   90    1170
# ...         ...    ...  ...     ...
# 1431         69  20544   86    1025
# 1432         72  19000   86    1015
# 1433         71  17016   86    1015
# 1434         70  16916   86    1015
# 1435         76      1  110    1114
#
# [1436 rows x 4 columns]

# %%
y=df["Price"]
y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1436, dtype: int64

# %%
x=df.drop(columns=["Price","Id","Doors","Cylinders","Gears","Model"])
x
# Out:
#       Age_08_04     KM   HP  Weight
# 0            23  46986   90    1165
# 1            23  72937   90    1165
# 2            24  41711   90    1165
# 3            26  48000   90    1165
# 4            30  38500   90    1170
# ...         ...    ...  ...     ...
# 1431         69  20544   86    1025
# 1432         72  19000   86    1015
# 1433         71  17016   86    1015
# 1434         70  16916   86    1015
# 1435         76      1  110    1114
#
# [1436 rows x 4 columns]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x, y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
#       Age_08_04      KM   HP  Weight
# 1178         72   93066  110    1075
# 1083         71  134660   72    1135
# 731          62   85000  110    1050
# 686          65  100550  110    1075
# 402          56  113997   72    1135
# ...         ...     ...  ...     ...
# 763          67   79762   86    1015
# 835          67   67762  110    1065
# 1216         70   85864   72    1135
# 559          50   39706  110    1080
# 684          68  101001  110    1075
#
# [1005 rows x 4 columns]

# %%
X_test
# Out:
#       Age_08_04      KM   HP  Weight
# 651          68  115071  110    1055
# 411          52   99323  110    1055
# 342          42   29640  110    1055
# 1298         78   71186  110    1050
# 483          56   62751  110    1050
# ...         ...     ...  ...     ...
# 1051         80  194765   72    1120
# 1374         69   57096   86    1025
# 549          48   43120   97    1030
# 864          68   64000  110    1075
# 1340         77   62595  110    1050
#
# [431 rows x 4 columns]

# %%
Y_train
# Out:
# 1178     8250
# 1083     5950
# 731     10450
# 686      8950
# 402      5150
#         ...
# 763      9130
# 835      9750
# 1216     8500
# 559     13500
# 684      8950
# Name: Price, Length: 1005, dtype: int64

# %%
Y_test
# Out:
# 651      7950
# 411     10950
# 342     14950
# 1298     7500
# 483      9900
#         ...
# 1051     6150
# 1374     8600
# 549     12500
# 864      8950
# 1340     8950
# Name: Price, Length: 431, dtype: int64

# %%
from sklearn import linear_model

# %%
lm=linear_model.LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
a=lm.intercept_

# %%
a
# Out:
# -6422.105717840106

# %%
b=lm.coef_
b
# Out:
# array([-1.18983501e+02, -2.13417967e-02,  2.20707328e+01,  2.14947229e+01])

# %%
y_predict_train=lm.predict(X_train)

# %%
y_predict_train
# Out:
# array([ 8559.49429701,  8241.78263007,  9384.10416324, ...,
#         9402.16044401, 12423.40319807,  8866.0811423 ])

# %%
plt.scatter(Y_train,y_predict_train)
plt.xlabel("Actual points")
plt.ylabel("Predicted points")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(Y_train,y_predict_train)
# Out:
# 0.8761119433310506

# %%
#For testing Data
y_test_predict=lm.predict(X_test)
y_test_predict
# Out:
# array([ 8135.90760458, 10375.73422897, 13052.72965658,  7775.18373385,
#        10572.83880228,  9737.29299631,  6438.88547653, 15994.10362346,
#        11346.70564403, 10588.50231247,  7138.60978279, 11278.98470727,
#        11907.59101915,  9862.69097115,  7374.68013742, 15870.29986061,
#        11189.30186679,  7770.15877008, 12947.70829005,  9012.11411753,
#         6336.02775679,  5689.90094022, 11762.56386882, 12173.07857236,
#        19159.859183  ,  7891.89903637, 14216.04391041,  6021.34722903,
#         9226.04886376,  7674.47280621, 11127.17061769,  7538.17489427,
#        16321.92181989,  7157.46034647, 11338.01119003, 13087.58148915,
#        10251.32140282, 12283.21882345,  9808.48087718,  8781.0348701 ,
#         8619.25969845, 10649.83700948,  9336.97389324, 17023.21278636,
#        10787.06391908,  6790.06553084,  9796.37168867,  7795.71752611,
#         8320.81485289,  8826.07169619, 19214.86040891,  8363.80563013,
# ...

# %%
r2_score(Y_test,y_test_predict)
# Out:
# 0.8109584109998484

# %%
plt.scatter(Y_test,y_test_predict)
plt.xlabel("Actual points")
plt.ylabel("Predicted points")
plt.show()

# %%
plt.scatter(Y_train,y_predict_train)
plt.plot(Y_test,y_test_predict)
plt.xlabel("Actual points")
plt.ylabel("Predicted points")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(Y_test,y_test_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13108\785410373.py in <module>
# ----> 1 mean_squared_error(Y_test,y_test_predict)
#
# NameError: name 'Y_test' is not defined
