# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\SHYAM SASHANK\OneDrive\Desktop\Data_Science\Assginment_CSV\banks.csv')
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
x=df.drop(columns=['y','job','marital','education','default','housing','loan','contact','month','poutcome'])
x.head()
# Out:
#    age  balance  day  duration  campaign  pdays  previous
# 0   58     2143    5       261         1     -1         0
# 1   44       29    5       151         1     -1         0
# 2   33        2    5        76         1     -1         0
# 3   47     1506    5        92         1     -1         0
# 4   33        1    5       198         1     -1         0

# %%
x.tail()
# Out:
#        age  balance  day  duration  campaign  pdays  previous
# 45206   51      825   17       977         3     -1         0
# 45207   71     1729   17       456         2     -1         0
# 45208   72     5715   17      1127         5    184         3
# 45209   57      668   17       508         4     -1         0
# 45210   37     2971   17       361         2    188        11

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
y=df[['y']]
y
# Out:
#          y
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# ...    ...
# 45206  yes
# 45207  yes
# 45208  yes
# 45209   no
# 45210   no
#
# [45211 rows x 1 columns]

# %%
y1=pd.get_dummies(y)
y1
# Out:
#        y_no  y_yes
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 45206     0      1
# 45207     0      1
# 45208     0      1
# 45209     1      0
# 45210     1      0
#
# [45211 rows x 2 columns]

# %%
lr.fit(x,y)
# Out:
# C:\Users\SHYAM SASHANK\anaconda3\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\SHYAM SASHANK\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predict=lr.predict(x)
predict
# Out:
# array(['no', 'no', 'no', ..., 'no', 'no', 'no'], dtype=object)

# %%
p1=pd.get_dummies(predict)
p1
# Out:
#        no  yes
# 0       1    0
# 1       1    0
# 2       1    0
# 3       1    0
# 4       1    0
# ...    ..  ...
# 45206   1    0
# 45207   1    0
# 45208   1    0
# 45209   1    0
# 45210   1    0
#
# [45211 rows x 2 columns]

# %%
a=pd.DataFrame(predict)

# %%
df[['LR_Predict']]=a
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# # #Method 2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.4)

# %%
x_train
# Out:
#        age  balance  day  duration  campaign  pdays  previous
# 25490   45       38   19       159         1    188         2
# 20631   34      520   12      1307         4     -1         0
# 3400    30     -256   15        51         5     -1         0
# 17277   48      917   28       103         5     -1         0
# 24790   30       33   18        36         1     -1         0
# ...    ...      ...  ...       ...       ...    ...       ...
# 30403   35      995    5        39         1     -1         0
# 21243   35      750   18       233        12     -1         0
# 42613   35      323   11       261         2     -1         0
# 43567   70      616   27       149         2    182         1
# 2732    46       57   14       194         4     -1         0
#
# [27126 rows x 7 columns]

# %%
x_test
# Out:
#        age  balance  day  duration  campaign  pdays  previous
# 14001   37     1403   10        91        15     -1         0
# 32046   36     -253   14      1073         1     -1         0
# 13318   47     -406    8       243         5     -1         0
# 42991   57      501   11       105         7    188         2
# 14237   33     -406   14       332         2     -1         0
# ...    ...      ...  ...       ...       ...    ...       ...
# 17247   28      111   28       230         2     -1         0
# 13270   38        0    8       452         3     -1         0
# 26058   37      510   19        67         2     90         6
# 14276   33      179   14       244         7     -1         0
# 28896   28       12   30        73         3    256         3
#
# [18085 rows x 7 columns]

# %%
y_train
# Out:
#          y
# 25490   no
# 20631  yes
# 3400    no
# 17277   no
# 24790   no
# ...    ...
# 30403   no
# 21243   no
# 42613  yes
# 43567   no
# 2732    no
#
# [27126 rows x 1 columns]

# %%
y_test
# Out:
#          y
# 14001   no
# 32046  yes
# 13318   no
# 42991   no
# 14237   no
# ...    ...
# 17247   no
# 13270   no
# 26058   no
# 14276   no
# 28896   no
#
# [18085 rows x 1 columns]

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\SHYAM SASHANK\anaconda3\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\SHYAM SASHANK\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lr.predict(x_train)

# %%
y_pred
# Out:
# array(['no', 'yes', 'no', ..., 'no', 'no', 'no'], dtype=object)

# %%
y_pred_test=lr.predict(x_test)

# %%
y_pred_test
# Out:
# array(['no', 'yes', 'no', ..., 'no', 'no', 'no'], dtype=object)

# %%
a1=pd.DataFrame(y_pred_test)
a1
# Out:
#          0
# 0       no
# 1      yes
# 2       no
# 3       no
# 4       no
# ...    ...
# 18080   no
# 18081   no
# 18082   no
# 18083   no
# 18084   no
#
# [18085 rows x 1 columns]

# %%
y1=pd.DataFrame(y_pred)

# %%
y1
# Out:
#          0
# 0       no
# 1      yes
# 2       no
# 3       no
# 4       no
# ...    ...
# 27121   no
# 27122   no
# 27123   no
# 27124   no
# 27125   no
#
# [27126 rows x 1 columns]

# %%
df[['LR_Pred2']]=y1
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y,predict)
print (confusion_matrix)
# Out:
# [[39291   631]
#  [ 4442   847]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y,predict))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.90      0.98      0.94     39922
#          yes       0.57      0.16      0.25      5289
#
#     accuracy                           0.89     45211
#    macro avg       0.74      0.57      0.59     45211
# weighted avg       0.86      0.89      0.86     45211

# %%
lr.predict_proba (x)[:,1]
# Out:
# array([0.08924362, 0.10391982, 0.12918551, ..., 0.23294333, 0.05585477,
#        0.23049723])

# %%
# ROC Graph

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr, tpr, thresholds = roc_curve(y1, lr.predict_proba (x)[:,1])

auc = roc_auc_score(y1, p1)

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='red', label='logit model ( area  = %0.2f)'%auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20572\2478212369.py in <module>
#       4 from sklearn.metrics import roc_auc_score
#       5
# ----> 6 fpr, tpr, thresholds = roc_curve(y1, lr.predict_proba (x)[:,1])
#       7
#       8 auc = roc_auc_score(y1, p1)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     209                     )
#     210                 ):
# --> 211                     return func(*args, **kwargs)
#     212             except InvalidParameterError as e:
#     213                 # When the function is just a wrapper around an estimator, we allow
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1092     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1093     """
# ...
